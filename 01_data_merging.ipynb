# %%
import pandas as pd
import numpy as np

# List of files and corresponding years
files = {
    "stats_2023.csv": 2023,
    "stats_2024.csv": 2024,
    "stats_2025.csv": 2025
}

# Load each CSV file, add a 'year' column, and store them in a list
dfs = [pd.read_csv(file, index_col=0).assign(year=year) for file, year in files.items()]

# Merge all dataframes into one
merged_df = pd.concat(dfs)

# Quick fix to create new columns (forgot to do so when year 2023 was initialized)
# merged_df["avg_earnings_per_article"] = round(merged_df["earnings"] / merged_df["number_articles"], 2)
# merged_df["avg_read_ratio"] = round(merged_df["reads"] / merged_df["views"] * 100, 2)

# Display the first few rows
merged_df.head()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 18
#      15 merged_df = pd.concat(dfs)
#      17 # Quick fix to create new columns (forgot to do so when year 2023 was initialized)
# ---> 18 merged_df["avg_earnings_per_article"] = round(merged_df["earnings"] / merged_df["number_articles"], 2)
#      19 merged_df["avg_read_ratio"] = round(merged_df["reads"] / merged_df["views"] * 100, 2)
#      21 # Display the first few rows
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     215     func = partial(expressions.evaluate, op)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     239 if op_str is not None:
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     128     _store_test_result(result is not None)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File c:\Users\Crypt-Logic\anaconda3\envs\myenv\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      71 if _TEST_MODE:
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ZeroDivisionError: float division by zero

# %%
merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 merged_df
#
# NameError: name 'merged_df' is not defined

# %%
merged_df = merged_df.set_index("year", append=True).swaplevel(0, 1).replace(0, np.nan)

# %%
merged_df
# Out:
#                 earnings  followers  follower_gain(change)  email_subscribers  \
# year
# 2023 January         NaN        NaN                    NaN                NaN
#      February        NaN        NaN                    NaN                NaN
#      March           NaN        NaN                    NaN                NaN
#      April           NaN        NaN                    NaN                NaN
#      May             NaN        NaN                    NaN                NaN
#      June            NaN        2.0                    2.0                NaN
#      July            NaN       48.0                   46.0                NaN
#      August        14.25       81.0                   33.0                NaN
#      September     10.71      108.0                   27.0                NaN
#      October        2.04      137.0                   29.0                3.0
#      November      15.48      178.0                   41.0                3.0
#      December     159.91      244.0                   66.0                5.0
# 2024 January      103.26      309.0                   65.0                3.0
#      February      39.82      358.0                   49.0                4.0
#      March         74.53      384.0                   26.0                5.0
#      April        206.51      472.0                   88.0                9.0
#      May          152.47      539.0                   67.0               11.0
#      June         196.38      643.0                  104.0               15.0
#      July         319.06      841.0                  198.0               19.0
#      August       413.91     1048.0                  207.0               21.0
#      September    676.92     1388.0                  340.0               27.0
#      October      463.29     1610.0                  230.0               30.0
#      November     435.48     1762.0                  172.0               29.0
#      December     298.96     1906.0                  144.0               31.0
# 2025 January      273.17     1975.0                   89.0               29.0
#      February     418.94     2071.0                   96.0               30.0
#      March           NaN        NaN                    NaN                NaN
#      April           NaN        NaN                    NaN                NaN
#      May             NaN        NaN                    NaN                NaN
#      June            NaN        NaN                    NaN                NaN
#      July            NaN        NaN                    NaN                NaN
#      August          NaN        NaN                    NaN                NaN
#      September       NaN        NaN                    NaN                NaN
#      October         NaN        NaN                    NaN                NaN
#      November        NaN        NaN                    NaN                NaN
#      December        NaN        NaN                    NaN                NaN
#
#                   views    reads  number_articles  avg_earnings_per_article  \
# year
# 2023 January        NaN      NaN              NaN                       NaN
#      February       NaN      NaN              NaN                       NaN
#      March          NaN      NaN              NaN                       NaN
#      April          NaN      NaN              NaN                       NaN
#      May            NaN      NaN              NaN                       NaN
#      June           NaN      NaN              NaN                       NaN
#      July         122.0     60.0              4.0                       NaN
#      August       181.0     83.0             11.0                      1.30
#      September    146.0     80.0             13.0                      0.82
#      October       91.0     46.0             13.0                      0.16
#      November     387.0    258.0             11.0                      1.41
#      December    5300.0   4000.0             16.0                      9.99
# 2024 January     4500.0   3200.0             15.0                      6.88
#      February    1200.0    863.0             10.0                      3.98
#      March       2700.0   1800.0             19.0                      3.92
#      April       6200.0   4200.0             15.0                     13.77
#      May         3700.0   2600.0             15.0                     10.16
#      June        5300.0   3800.0             16.0                     12.27
#      July       11700.0   7800.0             21.0                     15.19
#      August     13200.0   9000.0             24.0                     17.25
#      September  22000.0  16200.0             25.0                     27.08
#      October    18300.0  12600.0             24.0                     19.30
#      November   18600.0  13100.0             24.0                     18.14
#      December   14300.0   9800.0             26.0                     11.50
# 2025 January    13300.0   9100.0             18.0                     15.18
#      February   11700.0   8200.0             15.0                     27.93
#      March          NaN      NaN              NaN                       NaN
#      April          NaN      NaN              NaN                       NaN
#      May            NaN      NaN              NaN                       NaN
#      June           NaN      NaN              NaN                       NaN
#      July           NaN      NaN              NaN                       NaN
#      August         NaN      NaN              NaN                       NaN
#      September      NaN      NaN              NaN                       NaN
#      October        NaN      NaN              NaN                       NaN
#      November       NaN      NaN              NaN                       NaN
#      December       NaN      NaN              NaN                       NaN
#
#                 avg_read_ratio
# year
# 2023 January               NaN
#      February              NaN
#      March                 NaN
#      April                 NaN
#      May                   NaN
#      June                  NaN
#      July                49.18
#      August              45.86
#      September           54.79
#      October             50.55
#      November            66.67
#      December            75.47
# 2024 January             71.11
#      February            71.92
#      March               66.67
#      April               67.74
#      May                 70.27
#      June                71.70
#      July                66.67
#      August              68.18
#      September           73.64
#      October             68.85
#      November            70.43
#      December            68.53
# 2025 January             68.42
#      February            70.09
#      March                 NaN
#      April                 NaN
#      May                   NaN
#      June                  NaN
#      July                  NaN
#      August                NaN
#      September             NaN
#      October               NaN
#      November              NaN
#      December              NaN

# %%
merged_df = merged_df.reset_index().rename(columns={"level_1": "month"})

# %%
# merged_df.to_csv("medium_data.csv", index=False)

# %% [markdown]
# ### Extra data
# I went back and manually calculated the average article "length" (in minutes) for each month, going as far back as possible.
# I don't have some of my older articles anymore, because I deleted them (even if medium still keeps track of my stats from those earlier months).
# I'm curious if there's a correlation between "article length" and any other features, so I am going to merge two dataframes together.

# %%
# read in the csv files as pandas dataframes
#  (the first csv file was orginally created)
average_article_len = pd.read_csv("average_article_length.csv")
medium_data = pd.read_csv("medium_data.csv")

# %%
average_article_len
# Out:
#         month  year  average_article_length(minutes)
# 0     January  2023                              NaN
# 1    February  2023                              NaN
# 2       March  2023                              NaN
# 3       April  2023                              NaN
# 4         May  2023                              NaN
# 5        June  2023                              NaN
# 6        July  2023                              NaN
# 7      August  2023                             4.16
# 8   September  2023                             4.66
# 9     October  2023                             4.53
# 10   November  2023                             4.40
# 11   December  2023                             4.33
# 12    January  2024                             5.60
# 13   February  2024                             6.00
# 14      March  2024                             5.00
# 15      April  2024                             6.92
# 16        May  2024                             6.06
# 17       June  2024                             6.50
# 18       July  2024                             6.90
# 19     August  2024                             6.12
# 20  September  2024                             6.87
# 21    October  2024                             7.12
# 22   November  2024                             5.19
# 23   December  2024                             5.19
# 24    January  2025                             5.94
# 25   February  2025                             6.13
# 26      March  2025                              NaN
# 27      April  2025                              NaN
# 28        May  2025                              NaN
# 29       June  2025                              NaN
# 30       July  2025                              NaN
# 31     August  2025                              NaN
# 32  September  2025                              NaN
# 33    October  2025                              NaN
# 34   November  2025                              NaN
# 35   December  2025                              NaN

# %%
medium_data
# Out:
#     year      month  earnings  followers  follower_gain(change)  \
# 0   2023    January       NaN        NaN                    NaN
# 1   2023   February       NaN        NaN                    NaN
# 2   2023      March       NaN        NaN                    NaN
# 3   2023      April       NaN        NaN                    NaN
# 4   2023        May       NaN        NaN                    NaN
# 5   2023       June       NaN        2.0                    2.0
# 6   2023       July       NaN       48.0                   46.0
# 7   2023     August     14.25       81.0                   33.0
# 8   2023  September     10.71      108.0                   27.0
# 9   2023    October      2.04      137.0                   29.0
# 10  2023   November     15.48      178.0                   41.0
# 11  2023   December    159.91      244.0                   66.0
# 12  2024    January    103.26      309.0                   65.0
# 13  2024   February     39.82      358.0                   49.0
# 14  2024      March     74.53      384.0                   26.0
# 15  2024      April    206.51      472.0                   88.0
# 16  2024        May    152.47      539.0                   67.0
# 17  2024       June    196.38      643.0                  104.0
# 18  2024       July    319.06      841.0                  198.0
# 19  2024     August    413.91     1048.0                  207.0
# 20  2024  September    676.92     1388.0                  340.0
# 21  2024    October    463.29     1610.0                  230.0
# 22  2024   November    435.48     1762.0                  172.0
# 23  2024   December    298.96     1906.0                  144.0
# 24  2025    January    273.17     1975.0                   89.0
# 25  2025   February    418.94     2071.0                   96.0
# 26  2025      March       NaN        NaN                    NaN
# 27  2025      April       NaN        NaN                    NaN
# 28  2025        May       NaN        NaN                    NaN
# 29  2025       June       NaN        NaN                    NaN
# 30  2025       July       NaN        NaN                    NaN
# 31  2025     August       NaN        NaN                    NaN
# 32  2025  September       NaN        NaN                    NaN
# 33  2025    October       NaN        NaN                    NaN
# 34  2025   November       NaN        NaN                    NaN
# 35  2025   December       NaN        NaN                    NaN
#
#     email_subscribers    views    reads  number_articles  \
# 0                 NaN      NaN      NaN              NaN
# 1                 NaN      NaN      NaN              NaN
# 2                 NaN      NaN      NaN              NaN
# 3                 NaN      NaN      NaN              NaN
# 4                 NaN      NaN      NaN              NaN
# 5                 NaN      NaN      NaN              NaN
# 6                 NaN    122.0     60.0              4.0
# 7                 NaN    181.0     83.0             11.0
# 8                 NaN    146.0     80.0             13.0
# 9                 3.0     91.0     46.0             13.0
# 10                3.0    387.0    258.0             11.0
# 11                5.0   5300.0   4000.0             16.0
# 12                3.0   4500.0   3200.0             15.0
# 13                4.0   1200.0    863.0             10.0
# 14                5.0   2700.0   1800.0             19.0
# 15                9.0   6200.0   4200.0             15.0
# 16               11.0   3700.0   2600.0             15.0
# 17               15.0   5300.0   3800.0             16.0
# 18               19.0  11700.0   7800.0             21.0
# 19               21.0  13200.0   9000.0             24.0
# 20               27.0  22000.0  16200.0             25.0
# 21               30.0  18300.0  12600.0             24.0
# 22               29.0  18600.0  13100.0             24.0
# 23               31.0  14300.0   9800.0             26.0
# 24               29.0  13300.0   9100.0             18.0
# 25               30.0  11700.0   8200.0             15.0
# 26                NaN      NaN      NaN              NaN
# 27                NaN      NaN      NaN              NaN
# 28                NaN      NaN      NaN              NaN
# 29                NaN      NaN      NaN              NaN
# 30                NaN      NaN      NaN              NaN
# 31                NaN      NaN      NaN              NaN
# 32                NaN      NaN      NaN              NaN
# 33                NaN      NaN      NaN              NaN
# 34                NaN      NaN      NaN              NaN
# 35                NaN      NaN      NaN              NaN
#
#     avg_earnings_per_article  avg_read_ratio  average_article_length(minutes)
# 0                        NaN             NaN                              NaN
# 1                        NaN             NaN                              NaN
# 2                        NaN             NaN                              NaN
# 3                        NaN             NaN                              NaN
# 4                        NaN             NaN                              NaN
# 5                        NaN             NaN                              NaN
# 6                        NaN           49.18                              NaN
# 7                       1.30           45.86                             4.16
# 8                       0.82           54.79                             4.66
# 9                       0.16           50.55                             4.53
# 10                      1.41           66.67                             4.40
# 11                      9.99           75.47                             4.33
# 12                      6.88           71.11                             5.60
# 13                      3.98           71.92                             6.00
# 14                      3.92           66.67                             5.00
# 15                     13.77           67.74                             6.92
# 16                     10.16           70.27                             6.06
# 17                     12.27           71.70                             6.50
# 18                     15.19           66.67                             6.90
# 19                     17.25           68.18                             6.12
# 20                     27.08           73.64                             6.87
# 21                     19.30           68.85                             7.12
# 22                     18.14           70.43                             5.19
# 23                     11.50           68.53                             5.19
# 24                     15.18           68.42                             5.94
# 25                     27.93           70.09                             6.13
# 26                       NaN             NaN                              NaN
# 27                       NaN             NaN                              NaN
# 28                       NaN             NaN                              NaN
# 29                       NaN             NaN                              NaN
# 30                       NaN             NaN                              NaN
# 31                       NaN             NaN                              NaN
# 32                       NaN             NaN                              NaN
# 33                       NaN             NaN                              NaN
# 34                       NaN             NaN                              NaN
# 35                       NaN             NaN                              NaN

# %%
# merge on year and month columns since they both have commonality
new_final_merged_df = pd.merge(medium_data, average_article_len, on=["year","month"], how='left')

# %%
# Re run this older code to overwrite the csv file to load into the second notebook
new_final_merged_df.to_csv("medium_data.csv", index=False)
